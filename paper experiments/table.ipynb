# %%
import pandas as pd
import numpy as np

mae = pd.read_csv('mse-low.csv', names=['label', 'function', 'dim', 'error', 'std'])

# %%
mae
# Out:
#         label  function  dim         error       std
# 0      Morris         1    2  1.293958e-03  0.500000
# 1       Sobol         1    2  3.301300e-02  0.468167
# 2        Fast         1    2  2.452920e-01  0.269311
# 3    RDB-Fast         1    2  1.413922e-01  0.695020
# 4       Delta         1    2  6.357209e-02  0.340206
# ..        ...       ...  ...           ...       ...
# 955      DGSM        24   20  2.611736e-04  0.050000
# 956        R2        24   20  1.856564e-10  0.050000
# 957   Pearson        24   20  4.666711e-02  0.180929
# 958        RF        24   20  1.962404e-03  0.050000
# 959    Linear        24   20  1.278311e-03  0.050000
#
# [960 rows x 5 columns]

# %%
res = mae.groupby(['label', 'dim'])['error']

reformed_array = {}

for group_name, df_group in res:
    if (group_name[1] == 2):
        reformed_array[group_name[0]] = []
    score = df_group.mean() * 1000
    std = df_group.std() * 1000
    reformed_array[group_name[0]].append(f"${score:.3f}E^"+"{-3}$")# (±$"+f"{std:.2f}"+")E^{-3}$")
    #print(group_name, reformed_array[group_name[0]])

for alg in reformed_array:
    print (alg, " & \t", " & \t".join(reformed_array[alg]), "\\\\")
# Out:
# DGSM  & 	 $12.330E^{-3}$ & 	$8.725E^{-3}$ & 	$5.128E^{-3}$ & 	$2.068E^{-3}$ \\
# Delta  & 	 $54.468E^{-3}$ & 	$23.244E^{-3}$ & 	$21.786E^{-3}$ & 	$20.541E^{-3}$ \\
# Fast  & 	 $266.618E^{-3}$ & 	$162.788E^{-3}$ & 	$143.613E^{-3}$ & 	$156.082E^{-3}$ \\
# Linear  & 	 $42.184E^{-3}$ & 	$17.170E^{-3}$ & 	$6.677E^{-3}$ & 	$2.267E^{-3}$ \\
# Morris  & 	 $2.480E^{-3}$ & 	$1.874E^{-3}$ & 	$0.578E^{-3}$ & 	$0.205E^{-3}$ \\
# Pearson  & 	 $26.782E^{-3}$ & 	$40.661E^{-3}$ & 	$42.800E^{-3}$ & 	$46.279E^{-3}$ \\
# R2  & 	 $220.030E^{-3}$ & 	$0.010E^{-3}$ & 	$0.001E^{-3}$ & 	$0.001E^{-3}$ \\
# RDB-Fast  & 	 $285.309E^{-3}$ & 	$422.613E^{-3}$ & 	$470.534E^{-3}$ & 	$498.994E^{-3}$ \\
# RF  & 	 $20.288E^{-3}$ & 	$14.772E^{-3}$ & 	$8.570E^{-3}$ & 	$4.066E^{-3}$ \\
# Sobol  & 	 $68.387E^{-3}$ & 	$55.010E^{-3}$ & 	$29.566E^{-3}$ & 	$23.682E^{-3}$ \\

# %%
import pandas as pd
import numpy as np

mae = pd.read_csv('mae.csv', names=['label', 'function', 'dim', 'error'])

# %%
mae
# Out:
#         label  function  dim         error
# 0      Morris         1    2  4.579072e-04
# 1       Sobol         1    2  5.873120e-03
# 2        Fast         1    2  2.318961e-02
# 3    RDB-Fast         1    2  1.079084e-02
# 4       Delta         1    2  1.101729e-02
# ..        ...       ...  ...           ...
# 955      DGSM        24   20  5.994942e-04
# 956        R2        24   20  1.557141e-07
# 957   Pearson        24   20  5.718062e-03
# 958        RF        24   20  7.346716e-04
# 959    Linear        24   20  7.310782e-04
#
# [960 rows x 4 columns]

# %%
res = mae.groupby(['label', 'dim'])['error']

reformed_array = {}

for group_name, df_group in res:
    if (group_name[1] == 2):
        reformed_array[group_name[0]] = []
    score = df_group.mean() * 1000
    std = df_group.std() * 1000
    reformed_array[group_name[0]].append(f"${score:.3f}E^"+"{-3}$")# (±$"+f"{std:.2f}"+")E^{-3}$")
    #print(group_name, reformed_array[group_name[0]])

for alg in reformed_array:
    print (alg, " & \t", " & \t".join(reformed_array[alg]), "\\\\")
# Out:
# DGSM  & 	 $2.862E^{-3}$ (±$7.14)E^{-3}$ & 	$2.500E^{-3}$ (±$4.63)E^{-3}$ & 	$1.718E^{-3}$ (±$2.32)E^{-3}$ & 	$0.876E^{-3}$ (±$1.57)E^{-3}$ \\
# Delta  & 	 $8.438E^{-3}$ (±$4.38)E^{-3}$ & 	$3.869E^{-3}$ (±$1.75)E^{-3}$ & 	$3.596E^{-3}$ (±$0.93)E^{-3}$ & 	$3.748E^{-3}$ (±$0.34)E^{-3}$ \\
# Fast  & 	 $18.788E^{-3}$ (±$7.21)E^{-3}$ & 	$12.738E^{-3}$ (±$1.95)E^{-3}$ & 	$10.996E^{-3}$ (±$1.33)E^{-3}$ & 	$10.818E^{-3}$ (±$0.81)E^{-3}$ \\
# Linear  & 	 $5.127E^{-3}$ (±$5.98)E^{-3}$ & 	$3.343E^{-3}$ (±$2.14)E^{-3}$ & 	$2.204E^{-3}$ (±$1.17)E^{-3}$ & 	$1.367E^{-3}$ (±$0.59)E^{-3}$ \\
# Morris  & 	 $0.453E^{-3}$ (±$0.35)E^{-3}$ & 	$0.459E^{-3}$ (±$0.26)E^{-3}$ & 	$0.250E^{-3}$ (±$0.16)E^{-3}$ & 	$0.137E^{-3}$ (±$0.08)E^{-3}$ \\
# Pearson  & 	 $3.412E^{-3}$ (±$2.11)E^{-3}$ & 	$5.166E^{-3}$ (±$1.89)E^{-3}$ & 	$5.577E^{-3}$ (±$1.62)E^{-3}$ & 	$6.209E^{-3}$ (±$1.25)E^{-3}$ \\
# R2  & 	 $0.776E^{-3}$ (±$3.56)E^{-3}$ & 	$0.017E^{-3}$ (±$0.04)E^{-3}$ & 	$0.005E^{-3}$ (±$0.01)E^{-3}$ & 	$0.003E^{-3}$ (±$0.01)E^{-3}$ \\
# RDB-Fast  & 	 $14.161E^{-3}$ (±$3.44)E^{-3}$ & 	$18.999E^{-3}$ (±$1.43)E^{-3}$ & 	$20.275E^{-3}$ (±$0.84)E^{-3}$ & 	$20.878E^{-3}$ (±$0.31)E^{-3}$ \\
# RF  & 	 $4.429E^{-3}$ (±$2.87)E^{-3}$ & 	$2.941E^{-3}$ (±$1.34)E^{-3}$ & 	$1.851E^{-3}$ (±$0.71)E^{-3}$ & 	$1.276E^{-3}$ (±$0.43)E^{-3}$ \\
# Sobol  & 	 $7.893E^{-3}$ (±$5.03)E^{-3}$ & 	$6.959E^{-3}$ (±$3.78)E^{-3}$ & 	$5.211E^{-3}$ (±$3.20)E^{-3}$ & 	$4.121E^{-3}$ (±$3.74)E^{-3}$ \\
